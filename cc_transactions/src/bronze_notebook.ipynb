# %%
print("Hello DAB")

# %%
dbutils.widgets.dropdown(
    name="catalog",
    defaultValue="dev",
    choices=["dev", "test", "prod"],
    label="Select Catalog"
)

# %%
if dbutils.widgets.get('catalog')=='dev':
    print("dev-run")
else:
    print('prod-run')
